# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from src.data import build_price_panel
from src.metrics import summarize_returns
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tickers = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "META",
    "NVDA", "JPM", "BAC", "XOM", "CVX",
    "UNH", "JNJ", "PG", "KO", "PEP",
    "WMT", "HD", "COST", "DIS", "NFLX",
    "TSLA", "AMD", "INTC", "ORCL", "CRM",
    "GS", "MS", "V", "MA", "ADBE"
]

start_date = "2020-01-01"
end_date = "2024-01-01"

panel = build_price_panel(
    tickers=tickers,
    start_date=start_date,
    end_date=end_date
)

panel.head()
# Out:
#         date ticker      close    ret_1d  fwd_ret_1d  fwd_ret_5d  vol_20d  \
# 0 2020-01-02   AAPL  72.333870       NaN   -0.009722    0.030897      NaN
# 1 2020-01-03   AAPL  71.630638 -0.009722    0.007968    0.043371      NaN
# 2 2020-01-06   AAPL  72.201416  0.007968   -0.004703    0.057238      NaN
# 3 2020-01-07   AAPL  71.861839 -0.004703    0.016086    0.047890      NaN
# 4 2020-01-08   AAPL  73.017838  0.016086    0.021241    0.026881      NaN
#
#    vol_20d_ann
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
panel.to_csv(PROJECT_ROOT / "data/processed/price_panel.csv", index=False)

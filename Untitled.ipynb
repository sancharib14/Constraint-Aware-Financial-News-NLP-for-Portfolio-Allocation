# %%
def f(n):
    return n-3

# %%
def f(n):
    if n <= 1:
        return 1
    return f(n-1) + f(n-2)

# %%
def f(n):
    if n < 10:
        return n
    return f(n//10) + (n%10)

# %%
f(92345)
# Out:
# 23
